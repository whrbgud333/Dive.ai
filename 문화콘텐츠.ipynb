# %% [markdown]
# # 문화콘텐츠 스토리 데이터셋 구조 분석
#
# **출처**: AI Hub - 145. 다양한 문화콘텐츠 스토리 데이터
# **경로**: `문화콘텐츠 스토리 데이터/145.다양한_문화콘텐츠_스토리_데이터/`

# %% [markdown]
# ## 1. 전체 폴더 구조
#
# ```
# 145.다양한_문화콘텐츠_스토리_데이터/
# └── 01-1.정식개방데이터/
#     ├── Training/
#     │   ├── 01.원천데이터/
#     │   │   ├── TS_01.영화/   (1,327개 JSON)
#     │   │   ├── TS_02.시리즈/ (1,297개 JSON)
#     │   │   ├── TS_03.소설/   (  168개 JSON)
#     │   │   └── TS_04.만화/   (  368개 JSON)
#     │   └── 02.라벨링데이터/
#     │       ├── TL_01.영화/   (1,327개 JSON)
#     │       ├── TL_02.시리즈/ (1,297개 JSON)
#     │       ├── TL_03.소설/   (  168개 JSON)
#     │       └── TL_04.만화/   (  368개 JSON)
#     └── Validation/
#         ├── 01.원천데이터/
#         │   ├── VS_01.영화/   (  104개 JSON)
#         │   ├── VS_02.시리즈/ (  205개 JSON)
#         │   ├── VS_03.소설/   (   35개 JSON)
#         │   └── VS_04.만화/   (   57개 JSON)
#         └── 02.라벨링데이터/
#             ├── VL_01.영화/   (  104개 JSON)
#             ├── VL_02.시리즈/ (  205개 JSON)
#             ├── VL_03.소설/   (   35개 JSON)
#             └── VL_04.만화/   (   57개 JSON)
# ```

# %% [markdown]
# ## 2. 파일 수 요약
#
# | 구분 | 영화 | 시리즈 | 소설 | 만화 | 합계 |
# |------|-----:|-------:|-----:|-----:|-----:|
# | Training 원천 | 1,327 | 1,297 | 168 | 368 | **3,160** |
# | Training 라벨링 | 1,327 | 1,297 | 168 | 368 | **3,160** |
# | Validation 원천 | 104 | 205 | 35 | 57 | **401** |
# | Validation 라벨링 | 104 | 205 | 35 | 57 | **401** |
# | **총계** | | | | | **7,122** |
#
# > 원천데이터와 라벨링데이터는 **동일한 ID**로 1:1 매핑됩니다.
# > 파일명 패턴: `{카테고리번호}_{작품번호}.json` (예: `01_0017.json`)

# %% [markdown]
# ## 3. JSON 스키마 상세
#
# ### 3-1. 원천데이터 (TS_\* / VS_\*)
#
# 스크립트 원문 텍스트를 문장 단위 배열로 저장합니다.
#
# ```json
# {
#   "id":    "01_0017",        // 파일명과 동일한 고유 ID
#   "type":  "movie",          // 콘텐츠 유형: movie | series | novel | comic
#   "title": "아이들이 보인다",  // 작품 제목
#   "year":  2003,              // 제작/출판 연도
#   "text": [                   // 스크립트/본문 문장 배열 (캐릭터명은 C001 등 익명 처리)
#     "C001은 지하철 노약자석 한구석에서 졸고 있다.",
#     "C001은 졸다가 눈을 가늘게 떴을 때 어떤 엄마와 아이를 본다.",
#     ...
#   ]
# }
# ```
#
# ### 3-2. 라벨링데이터 (TL_\* / VL_\*)
#
# 원천데이터에 스토리 분석 레이블과 씬(unit) 단위 구조를 추가합니다.
#
# ```json
# {
#   "id":            "01_0017",
#   "type":          "movie",
#   "title":         "아이들이 보인다",
#   "genre":         ["스릴러", "공포(호러)", "드라마"],  // 복수 장르
#   "year":          2003,
#   "theme":         "발견",                             // 작품 핵심 테마
#   "concept":       "C001은 퇴근길에...",               // 한 줄 줄거리
#   "structure":     "스토리헬퍼 15단계",                // 스토리 구조 프레임워크
#   "motif":         "갑작스런 사고",                    // 주요 모티프
#   "main_character":"방어적임",                         // 주인공 성격 유형
#   "conflict":      "C001은 집에 보이는 귀신이...",    // 주요 갈등
#   "characters":    ["C001", "C002", ...],              // 등장인물 목록
#   "units": [
#     {
#       "id":         "01_0017_01",     // 씬 ID
#       "next_id":    "01_0017_02",     // 다음 씬 ID (연결 구조)
#       "characters": ["C001", "C003"],// 해당 씬 등장인물
#       "stage":      "Opening Salvo", // 스토리 단계 (영문)
#       "storyline":  "C001은 지하철 안에서...", // 씬 요약
#       "unit_motif": "긴장감",          // 씬 모티프
#       "story_scripts": [
#         {
#           "type":      "narrative",   // narrative | dialogue
#           "location":  "지하철 열차 안",
#           "character": ["C001"],
#           "act":       "공개하다/드러내다", // 행동 레이블
#           "emotion":   "피곤하다",          // 감정 레이블
#           "content":   "C001은 지하철 노약자석 한구석에서 졸고 있다."
#         },
#         ...
#       ]
#     },
#     ...
#   ]
# }
# ```

# %% [markdown]
# ## 4. 필드 정리
#
# > 실제 데이터 확인 결과, **영화/시리즈/소설/만화 4개 카테고리 모두 동일한 스키마**를 공유합니다.
#
# ### 4-1. 원천데이터 필드
#
# | 필드 | 타입 | 설명 |
# |------|------|------|
# | `id` | string | 고유 ID. `{카테고리번호}_{작품번호}` 형식 (예: `01_0017`). 라벨링데이터와 1:1 매핑 |
# | `type` | string | 콘텐츠 유형: `movie` / `series` / `novel` / `comic` |
# | `title` | string | 작품명 |
# | `year` | int | 제작/출판 연도 |
# | `text` | array\<string\> | 전체 스크립트/본문을 문장 단위 배열로 저장. 캐릭터명은 C001 등으로 익명 처리 |
#
# ### 4-2. 라벨링데이터 필드 — 작품 레벨
#
# | 필드 | 타입 | 설명 |
# |------|------|------|
# | `id` | string | 원천데이터와 동일한 고유 ID |
# | `type` | string | 콘텐츠 유형: `movie` / `series` / `novel` / `comic` |
# | `title` | string | 작품명 |
# | `year` | int | 제작/출판 연도 |
# | `genre` | array\<string\> | 복수 장르 배열 (예: `["스릴러", "공포(호러)", "드라마"]`) |
# | `theme` | string | 작품 핵심 테마 키워드 (예: `"발견"`) |
# | `concept` | string | 한 줄 줄거리 요약 |
# | `structure` | string | 스토리 구조 프레임워크 (예: `"스토리헬퍼 15단계"`) |
# | `motif` | string | 작품 전체 모티프 (예: `"갑작스런 사고"`) |
# | `main_character` | string | 주인공 성격 유형 (예: `"방어적임"`) |
# | `conflict` | string | 주요 갈등 서술 |
# | `characters` | array\<string\> | 등장인물 ID 목록 (예: `["C001", "C002", ...]`) |
# | `units` | array\<object\> | 씬(unit) 단위 분석 배열 → 아래 4-3 참고 |
#
# ### 4-3. 라벨링데이터 필드 — 씬(unit) 레벨
#
# | 필드 | 타입 | 설명 |
# |------|------|------|
# | `units[].id` | string | 씬 고유 ID (예: `"01_0017_01"`) |
# | `units[].prev_id` | string | 이전 씬 ID (첫 씬은 null) |
# | `units[].next_id` | string | 다음 씬 ID (마지막 씬은 null) |
# | `units[].characters` | array\<string\> | 해당 씬 등장인물 ID 목록 |
# | `units[].stage` | string | 스토리 단계명, 영문 (스토리헬퍼 15단계 기준, 예: `"Opening Salvo"`) |
# | `units[].storyline` | string | 씬 내용 요약 |
# | `units[].unit_motif` | string | 씬 단위 모티프 (예: `"긴장감"`) |
# | `units[].causality` | string | 씬 간 인과관계 서술 |
# | `units[].story_scripts` | array\<object\> | 문장별 상세 레이블 배열 → 아래 4-4 참고 |
#
# ### 4-4. 라벨링데이터 필드 — 스크립트(story_scripts) 레벨
#
# | 필드 | 타입 | 설명 |
# |------|------|------|
# | `units[].story_scripts[].type` | string | 문장 유형: `narrative` (지문) / `dialogue` (대사) |
# | `units[].story_scripts[].location` | string | 해당 문장의 배경 장소 (예: `"지하철 열차 안"`) |
# | `units[].story_scripts[].character` | array\<string\> | 해당 문장의 등장인물 ID 목록 |
# | `units[].story_scripts[].act` | string | 행동 레이블 (예: `"공개하다/드러내다"`) |
# | `units[].story_scripts[].emotion` | string | 감정 레이블 (예: `"피곤하다"`) |
# | `units[].story_scripts[].content` | string | 원문 문장 텍스트 |

# %% [markdown]
# ## 5. 스토리 구조 프레임워크
#
# `units[].stage` 필드에 사용되는 레이블 체계입니다.
# 데이터셋에는 두 가지 프레임워크가 혼재합니다.
#
# ---
#
# ### 5-1. 프레임워크 분포
#
# | 프레임워크 | 영화 | 시리즈 | 소설 | 만화 | 합계 | 비율 |
# |-----------|-----:|-------:|-----:|-----:|-----:|-----:|
# | 스토리헬퍼 15단계 | 1,422 | 1,495 | 189 | 406 | **3,512개** | 98.6% |
# | 영웅의 12단계 | 9 | 7 | 14 | 19 | **49개** | 1.4% |
#
# > 영웅의 12단계는 **판타지/액션 장르에 집중**되어 있습니다.
# > 49개 파일이지만 실제 고유 타이틀은 더 적습니다 — 시리즈 각 권이 별도 파일로 저장된 것 (예: 소드 앤 실드 1~11권).
#
# ---
#
# ### 5-2. 스토리헬퍼 15단계 (98.6%)
#
# **스토리헬퍼**는 한국콘텐츠진흥원(KOCCA)이 만든 스토리 창작 도구로, 영화/드라마 서사를 15개 단계로 분석하는 프레임워크입니다.<br>
# 해당 데이터셋에는 빠진 단계와 추가된 단계가 있습니다.
#
# | 순서 | stage | 의미 |
# |------|-------|------|
# | 1 | `Opening Salvo` | 작품의 첫 장면, 분위기/세계관 제시 |
# | 2 | `Main Character` | 주인공 소개, 현재 상태와 결핍 제시 |
# | 3 | `Setting-up` | 사건이 일어날 배경과 관계 설정 |
# | 4 | `1st Accident` | 첫 번째 사건 발생, 주인공의 일상이 흔들림 |
# | 5 | `Villains Move` | 적대자/갈등 요소가 본격적으로 움직임 |
# | 6 | `Doubts & Debate` | 주인공이 갈등하고 선택을 고민 |
# | 7 | `Making a Choice` | 주인공이 결단을 내림 |
# | 8 | `Choice to Fight` | 싸우기로 결심, 본격적인 행동 시작 |
# | 9 | `2nd Accident` | 두 번째 위기, 상황이 더 악화됨 |
# | 10 | `Innermost Cave` | 주인공이 가장 위험하고 어두운 상황에 처함 |
# | 11 | `Defeat` | 주인공이 패배하거나 최대 위기를 맞음 |
# | 12 | `Dark Night of Soul` | 절망의 끝, 포기 직전의 순간 |
# | 13 | `Trailer Moments` | 반전/각성, 클라이맥스 직전 긴장 최고조 |
# | 14 | `Climax` | 최종 대결, 모든 갈등이 폭발 |
# | 15 | `Denouement` | 결말, 갈등 해소 후 새로운 일상 |
#
# ---
#
# #### 실제 데이터 기준 — 스토리헬퍼 16단계
#
# > 위 공식 15단계 목록과 실제 데이터에 사용된 stage 레이블이 일부 다릅니다.
# > `Dark Night of Soul` / `Climax` / `Denouement` 3종은 데이터에 없고,
# > `Ups & Downs` / `Resurrection` / `Another Story` / `Final Salvo` 4종이 대신 사용됩니다.
# > 아래 순서는 서사 흐름 상 위치를 추정한 것입니다 (공식 문서 기준 아님).
#
# | 순서 | stage | 의미 | 씬 수 |
# |------|-------|------|------:|
# | 1 | `Opening Salvo` | 작품의 첫 장면, 분위기/세계관 제시 | 3,745 |
# | 2 | `Main Character` | 주인공 소개, 현재 상태와 결핍 제시 | 4,865 |
# | 3 | `Setting-up` | 사건이 일어날 배경과 관계 설정 | 8,380 |
# | 4 | `1st Accident` | 첫 번째 사건 발생, 주인공의 일상이 흔들림 | 7,471 |
# | 5 | `Villains Move` | 적대자/갈등 요소가 본격적으로 움직임 | 6,516 |
# | 6 | `Doubts & Debate` | 주인공이 갈등하고 선택을 고민 | 7,139 |
# | 7 | `Making a Choice` | 주인공이 결단을 내림 | 7,394 |
# | 8 | `Choice to Fight` | 싸우기로 결심, 본격적인 행동 시작 | 6,292 |
# | 9 | `Ups & Downs` | 본격적인 갈등과 소소한 성공/실패의 반복 | 4,105 |
# | 10 | `2nd Accident` | 두 번째 위기, 상황이 더 악화됨 | 7,658 |
# | 11 | `Innermost Cave` | 주인공이 가장 위험하고 어두운 상황에 처함 | 4,546 |
# | 12 | `Defeat` | 주인공이 패배하거나 최대 위기를 맞음 | 5,446 |
# | 13 | `Resurrection` | 패배를 딛고 주인공이 다시 일어섬 | 3,963 |
# | 14 | `Another Story` | 주인공 외 인물/서브플롯의 이야기가 전개됨 | 3,836 |
# | 15 | `Trailer Moments` | 반전/각성, 클라이맥스 직전 긴장 최고조 | 3,492 |
# | 16 | `Final Salvo` | 모든 갈등이 최종적으로 해결되고 마무리됨 | 3,576 |
#
# ---
#
# ### 5-3. 영웅의 12단계 (1.4%)
#
# 조셉 캠벨의 영웅 서사 프레임워크(Hero's Journey)를 기반으로 한 12단계입니다.
# **stage 레이블이 한국어**로 되어 있어 스토리헬퍼 15단계와 체계가 다릅니다.
#
# | 순서 | stage | 의미 |
# |------|-------|------|
# | 1 | `일상세계` | 영웅의 평범한 일상, 출발 전 상태 |
# | 2 | `모험에의 소명` | 영웅이 모험/사건으로 부름을 받음 |
# | 3 | `소명부활의 거부` | 영웅이 처음엔 소명을 거부하거나 망설임 |
# | 4 | `정신적 스승과의 만남` | 조언자/멘토를 만나 도움을 받음 |
# | 5 | `첫 관문의 통과` | 일상 세계를 벗어나 모험 세계로 진입 |
# | 6 | `시험, 협력자, 적대자` | 시련을 겪으며 동료와 적을 만남 |
# | 7 | `동굴 가장 깊은 곳으로의 진입` | 가장 위험한 장소/상황에 접근 |
# | 8 | `시련` | 최대 위기, 죽음에 가까운 시험을 통과 |
# | 9 | `보상` | 시련을 이겨내고 목표물/능력을 획득 |
# | 10 | `귀환의 길` | 일상 세계로 돌아가는 여정 시작 |
# | 11 | `부활` | 마지막 시험, 완전한 변화를 겪고 정화됨 |
# | 12 | `영약을 가지고 귀환` | 얻은 것을 가지고 일상으로 완전히 귀환 |
#
# #### 영웅의 12단계 적용 작품 목록
#
# **영화 (9개 파일 / 9개 타이틀)**
#
# | 제목 | 연도 | 장르 | 테마 |
# |------|------|------|------|
# | 괴물 잡는 히어로! | 2021 | SF, 판타지, 액션 | 구출 |
# | 꿈을 지켜라 | 2012 | 액션, 판타지 | 모험 |
# | 나를 내버려둬 | 2009 | 드라마 | 모험 |
# | 용과 친구가 되다 | 2021 | 판타지, 액션 | 성숙 |
# | 우정의 아름다움 | 2021 | 판타지 | 모험 |
# | 일어나 보니 시간이 | 2022 | 드라마 | 성숙 |
# | 찾아내라, 전설! | 2012 | 판타지, 액션 | 모험 |
# | 초인간 | 2014 | 액션 | 추적 |
# | 힘찬 주먹을 | 2017 | 판타지, 액션, 전쟁 | 모험 |
#
# **시리즈 (7개 파일 / 2개 타이틀)**
#
# | 제목 | 연도 | 장르 | 비고 |
# |------|------|------|------|
# | 레전드 | 2019 | 판타지, 액션 | 1~2권 |
# | 야망들 | 2013~2014 | 스릴러, 드라마 | 2~6권 |
#
# **소설 (14개 파일 / 4개 타이틀)**
#
# | 제목 | 연도 | 장르 | 비고 |
# |------|------|------|------|
# | 소드 앤 실드 | 2019 | 판타지, 액션 | 1~11권 |
# | 같이 나가자 | 2022 | 멜로/로맨스, SF | 1권 |
# | 알지 못했던 힘 | 2015 | 판타지, 액션 | 단편 |
# | 죽을수록 강해져! | 2018 | SF, 판타지 | 1권 |
#
# **만화 (19개 파일 / 4개 타이틀)**
#
# | 제목 | 연도 | 장르 | 비고 |
# |------|------|------|------|
# | 노력형 영웅이 되었습니다 | 2014 | 판타지, 액션 | 2~12권 |
# | 괴물과 나 | 2018 | 드라마, 판타지 | 1~3권 |
# | 눈 떠 보니 이세계 | 2009 | 드라마, 멜로/로맨스, 판타지 | 1~3권 |
# | 소년은 가문을 구한다 | 2013 | 액션, 공포(호러), 판타지 | 1~2권 |
#
# ---
#
# ### 5-4. 두 프레임워크 처리 방법
#
# 두 프레임워크는 **stage 레이블 언어부터 다릅니다** (영문 vs 한국어).
# 캐릭터 채팅 앱 특성상 **판타지 장르가 핵심**이므로, 영웅의 12단계 49개 작품을 살려서 활용합니다.
#
# | 처리 항목 | 방법 | 근거 |
# |----------|------|------|
# | **임베딩** | `unit_motif + storyline` 기준으로 그대로 사용 | 두 필드는 프레임워크 무관 — 유사도 검색 품질에 영향 없음 |
# | **RAG 프롬프트** | stage 레이블 그대로 출력 | 영문이면 영문, 한국어면 한국어 — LLM이 맥락 이해 가능 |
# | **구조 설계 통계** | stage 통계를 프레임워크별로 분리 저장 | 레이블 체계가 달라 혼합 시 통계 오염 |
#
# **`framework` 필드 태깅** — 전처리 시 모든 작품/씬에 아래 값을 추가합니다:
#
# | 값 | 적용 대상 |
# |----|---------|
# | `"storyhelper"` | structure에 "스토리헬퍼" 포함 (3,512개, 기본값) |
# | `"hero_journey"` | structure에 "영웅" 포함 (49개) |
#
# `genre_stats.json`에는 `top_stages_storyhelper` / `top_stages_hero_journey` 두 키로 분리 저장합니다.
# `unit_motif`, `theme`, `work_motif` 등 나머지 통계는 프레임워크 통합으로 집계합니다.
#
# #### 영웅의 12단계 활용 방향 (판타지 장르)
#
# 판타지 570개 작품 중 스토리헬퍼 531개(93%), 영웅의 12단계 39개(7%).
#
# | 용도 | 프레임워크 | 방식 |
# |------|------------|------|
# | **기승전결 구조 설계** | 스토리헬퍼 15단계 **(메인)** | 데이터 93% 기반 — 서사 구조 설계의 기준 프레임워크 |
# | **판타지 감정/분위기 묘사** | 영웅의 12단계 **(보조)** | `일상세계`, `시련`, `귀환의 길` 등 stage 레이블을 분위기·감정선 묘사에 참조 |
#
# > 벡터 DB 검색 시: `framework="storyhelper"` 우선 검색, 판타지 분위기 보강이 필요할 때만 `framework="hero_journey"` 씬 추가 검색.
#
# ---

# %% [markdown]
# ## 6. 데이터 로드 예시 코드

# %%
import json
import os
from pathlib import Path

BASE_DIR = Path("문화콘텐츠 스토리 데이터/145.다양한_문화콘텐츠_스토리_데이터/01-1.정식개방데이터")

# 카테고리 매핑
CATEGORIES = {
    "01": "영화",
    "02": "시리즈",
    "03": "소설",
    "04": "만화",
}

def load_pair(split: str, category: str, file_id: str):
    """원천데이터와 라벨링데이터를 ID로 한 쌍 불러오기.
    
    split: 'Training' | 'Validation'
    category: '01'~'04'
    file_id: e.g. '01_0017'
    """
    prefix_src = "TS" if split == "Training" else "VS"
    prefix_lbl = "TL" if split == "Training" else "VL"
    cat_name = CATEGORIES[category]

    src_path = BASE_DIR / split / "01.원천데이터" / f"{prefix_src}_{category}.{cat_name}" / f"{file_id}.json"
    lbl_path = BASE_DIR / split / "02.라벨링데이터" / f"{prefix_lbl}_{category}.{cat_name}" / f"{file_id}.json"

    with open(src_path, encoding="utf-8") as f:
        source = json.load(f)
    with open(lbl_path, encoding="utf-8") as f:
        label = json.load(f)

    return source, label


def iter_all(split: str = "Training", category: str = "01"):
    """특정 split/카테고리의 모든 (원천, 라벨링) 쌍을 순회."""
    prefix_src = "TS" if split == "Training" else "VS"
    cat_name = CATEGORIES[category]
    src_dir = BASE_DIR / split / "01.원천데이터" / f"{prefix_src}_{category}.{cat_name}"

    for json_file in sorted(src_dir.glob("*.json")):
        file_id = json_file.stem
        yield load_pair(split, category, file_id)


# 사용 예시
src, lbl = load_pair("Training", "01", "01_0017")
print("제목:", src["title"])
print("장르:", lbl["genre"])
print("테마:", lbl["theme"])
print("씬 수:", len(lbl["units"]))
print("첫 번째 씬 stage:", lbl["units"][0]["stage"])

# %%
# 전체 파일 수 확인
stats = {}
for split in ["Training", "Validation"]:
    for cat in CATEGORIES:
        prefix = "TS" if split == "Training" else "VS"
        cat_name = CATEGORIES[cat]
        d = BASE_DIR / split / "01.원천데이터" / f"{prefix}_{cat}.{cat_name}"
        count = len(list(d.glob("*.json"))) if d.exists() else 0
        stats[f"{split}/{cat_name}"] = count

for k, v in stats.items():
    print(f"{k}: {v}개")
print("합계:", sum(stats.values()), "(원천 기준)")

# %% [markdown]
# ## 7. 전처리 코드 사용 필드 — 실제 값 목록
#
# 전처리 코드(코드셀 6·7번)에서 구조 설계 또는 메타데이터 RAG에 사용되는 필드와, 각 필드의 실제 값 전체를 빈도순으로 정리합니다.
#
# > 전체 집계 기준: Training + Validation 전체 3,561개 작품 / 89,851개 씬
#
# ### 필드 용도 요약
#
# | 필드 | 위치 | 구조 설계(코드셀 6) | 메타데이터 RAG(코드셀 7) |
# |------|------|:-----------------:|:--------------------:|
# | `genre` | 작품 레벨 | 집계 기준(분류 키) | 필터 |
# | `theme` | 작품 레벨 | Top 테마 통계 | 출력 컨텍스트 |
# | `motif` | 작품 레벨 | Top 작품 모티프 통계 | 모티프 키워드 필터 |
# | `main_character` | 작품 레벨 | Top 주인공 유형 통계 | — |
# | `stage` | 씬 레벨 | Top 서사 단계 통계(프레임워크별) | 필터 + 출력 |
# | `unit_motif` | 씬 레벨 | Top 씬 모티프 통계 | 모티프 키워드 필터 + 출력 |
# | `storyline` | 씬 레벨 | — | 출력 컨텍스트(자유 텍스트, 목록 제외) |
# | `emotion` | 스크립트 레벨 | stage별 지배 감정 통계 | — |
#
# ---
#
# ### 7-1. `genre` — 장르 (작품 레벨)
#
# 총 **10종** / 작품 하나에 복수 장르 가능 (배열 필드)
#
# | 장르 | 작품 수(중복 포함) |
# |------|----------------:|
# | 드라마 | 2,264 |
# | 멜로/로맨스 | 1,450 |
# | 스릴러 | 786 |
# | 판타지 | 570 |
# | 액션 | 434 |
# | 미스터리 | 247 |
# | 코미디 | 243 |
# | SF | 179 |
# | 공포(호러) | 100 |
# | 전쟁 | 75 |
#
# ---
#
# ### 7-2. `theme` — 작품 테마 (작품 레벨)
#
# 총 **22종**
#
# | 테마 | 작품 수 |
# |------|-------:|
# | 사랑 | 1,100 |
# | 도전 | 376 |
# | 성숙 | 249 |
# | 모험 | 222 |
# | 추적 | 203 |
# | 몰락 | 179 |
# | 복수 | 169 |
# | 구출 | 163 |
# | 금지된 사랑 | 151 |
# | 수수께끼 | 108 |
# | 라이벌 | 95 |
# | 추구 | 93 |
# | 발견 | 84 |
# | 탈출 | 64 |
# | 상승 | 57 |
# | 지독한 행위 | 56 |
# | 희생자 | 48 |
# | 순애보 | 45 |
# | 희생 | 38 |
# | 변모 | 25 |
# | 유혹 | 18 |
# | 변신 | 18 |
#
# ---
#
# ### 7-3. `motif` — 작품 모티프 (작품 레벨)
#
# 총 **179종** / 빈도순
#
# **빈도 10 이상 (87종)**
#
# | 모티프 | 작품 수 |
# |--------|-------:|
# | 갑작스런 사고 | 152 |
# | 삼각관계 | 117 |
# | 짝사랑 | 112 |
# | 첫눈에 반한 사랑 | 94 |
# | 강제된 과업 | 88 |
# | 낯선 곳으로의 이주 | 85 |
# | 사랑하는 사람의 죽음 | 74 |
# | 오해(착각) | 68 |
# | 신분위장 | 61 |
# | 계급을 초월한 사랑 | 61 |
# | 부당한 차별 | 56 |
# | 누명 | 55 |
# | 연인 상실 | 54 |
# | 연쇄 살인 | 53 |
# | 운명에 대한 반역 | 51 |
# | 복수혈전 | 50 |
# | 수수께끼 | 49 |
# | 청소년기 일탈 | 48 |
# | 납치 | 48 |
# | 출세주의자 | 46 |
# | 미결의 살인사건 | 46 |
# | 세대를 초월한 우정 | 43 |
# | 사랑의 연기 | 42 |
# | 간통 | 40 |
# | 기억상실증 | 37 |
# | 희생하는 부모 | 34 |
# | 뜻밖의 초능력 | 34 |
# | 덜떨어진 영웅 | 31 |
# | 나쁜남자에게 반하기 | 31 |
# | 감금 | 31 |
# | 고뇌하는 깡패 | 31 |
# | 불우한 천재 | 31 |
# | 예언 | 31 |
# | 도망자 | 30 |
# | 차원이동 | 30 |
# | 옛 연인의 출현 | 30 |
# | 갑작스런 병 | 29 |
# | 대전격투 | 29 |
# | 소년 영웅 | 29 |
# | 취향의 재발견 | 28 |
# | 거짓된 진술 | 27 |
# | 수사의뢰 | 26 |
# | 도시 재난 | 25 |
# | 아웃사이더 | 25 |
# | 추격자 | 24 |
# | 아름다운 불륜 | 24 |
# | 고발 | 23 |
# | 중년의 위기 | 23 |
# | 시한부 선고 | 22 |
# | 적과의 사랑 | 22 |
# | 명예손상 | 22 |
# | 이혼 | 22 |
# | 버려진 아이 | 22 |
# | 부부싸움 | 21 |
# | 보물찾기 | 21 |
# | 빙의 | 20 |
# | 우울증 | 19 |
# | 가족분열(이산가족) | 19 |
# | 탈옥 | 19 |
# | 동물과의 우정 | 18 |
# | 고등사기꾼 | 18 |
# | 기이한 선생 | 18 |
# | 숨겨진 연인 | 18 |
# | 시간여행 | 17 |
# | 노년기 과제 | 17 |
# | 배반자 | 17 |
# | 사이코패스 | 17 |
# | 감춰진 혈통찾기 | 17 |
# | 돈을 노리는 유혹자(Gold Digger) | 17 |
# | 강박증 | 17 |
# | 사고사 | 17 |
# | 죄의 고백 | 17 |
# | 몰락한 귀족 | 17 |
# | 바람둥이 | 16 |
# | 광기어린 사랑 | 16 |
# | 부모 찾기 | 16 |
# | 전쟁 발발 | 16 |
# | 구세주 출현 | 15 |
# | 우발적 살인 | 15 |
# | 귀신소환 | 15 |
# | 횡재 | 15 |
# | 이계방문 | 15 |
# | 도둑 | 14 |
# | 파산 | 14 |
# | 인질 | 14 |
# | 지인의 실종 | 14 |
# | 강간 | 13 |
# | 희생하는 자식 | 13 |
# | 우월한 하급자 | 13 |
# | 저주 | 13 |
# | 뜻밖의 편지 | 13 |
# | 신분상승결혼(신데렐라) | 13 |
#
# **빈도 9 이하 (92종)**
#
# 고립된 남녀(12), 위험한 비밀결혼(12), 테러(12), 나이 차를 극복한 사랑(12), 불청객(12), 악동(11), 동성애자(11), 귀향(11), 다중인격(11), 자살(11), 도박(11), 퇴마사(11), 저승방문자(11), 환생(10), 성정체성 혼란(10), 뱀파이어(9), 거대괴수(9), 유령(9), 부패경찰(9), 독재정치(9), 도제수련(9), 전우 구출(9), 집단광기(9), 식민지화(9), 아동학대(9), 외계인 침입(9), 이지메(9), 적군과의 우정(8), 첫관계(8), 외상 후 스트레스성 장애(PTSD)(7), 대체역사(7), 살인청부업자(7), 대항해와 원정(7), 팜므파탈(요부)(7), 생물학 재앙(6), 마약거래자(6), 고귀한 창녀(6), 장애인(6), 공황장애(6), 지구종말(6), 마법사(마녀)(6), 지리적 고립(6), 변장(6), 이간질(6), 똑똑한 바보(5), 원나잇스탠드(5), 가문의 여주인(5), 경계성 인격장애(5), 강도(5), 치매(5), 돌연변이(뮤턴트)(5), 용호상박(4), 형제 간의 경쟁(4), 아동 유괴(4), 사이보그(4), 유랑자(집시)(4), 스토킹(4), 자폐증(4), 좀비(4), 무인도 조난(3), 아내강탈(3), 저주받은 장소(3), 고상한 야만인(3), 구혼시험(3), 스와핑(3), 마조히즘(3), 복제인간(3), 알코올 중독(3), 반인반수(3), 도플갱어(3), 백치미인(2), 고리대금업자(2), 순교자(2), 천사(2), 학대하는 계부(계모)(2), 고부갈등(2), 사람이 된 인형(2), 무장봉기(2), 악마적인 예술가(2), 악마의 아이(2), 의적(2), 천재지변(2), 모반(2), 대학살(2), 시라노 콤플렉스(2), 근친상간(1), 비대칭전투(1), 악마와의 계약(1), 고귀한 하녀(1), 피그말리온(1), 지배자 희롱(1), 동반자살(1), 집착광공(1), 전쟁포로(1), 파업(1), 롤리타(1), 사랑에 빠진 노인(1), 불면증(1), 처녀영웅(1), 성생활 장애(1), 인공동면(1), 미지의 후견인(1)
#
# ---
#
# ### 7-4. `main_character` — 주인공 유형 (작품 레벨)
#
# 총 **107종** / 빈도순
#
# **빈도 10 이상 (67종)**
#
# | 주인공 유형 | 작품 수 |
# |------------|-------:|
# | 아픈 기억이 있음 | 292 |
# | 회사원 | 264 |
# | 제자/학생 | 171 |
# | 경찰 | 112 |
# | 예술가 | 92 |
# | 스승/교사 | 91 |
# | 운동선수 | 91 |
# | 순진함 | 90 |
# | 고아 | 85 |
# | 미인 | 77 |
# | 천재 | 76 |
# | 살인자/범죄자 | 75 |
# | 카리스마 있음 | 72 |
# | 당당함 | 71 |
# | 변호사 | 65 |
# | 용감함 | 58 |
# | 거지 | 55 |
# | 엉뚱함 | 53 |
# | CEO(사장/회장) | 48 |
# | 황족(왕족) | 48 |
# | 순정파 | 47 |
# | 의사 | 47 |
# | 재벌 | 47 |
# | 청소년 | 46 |
# | 계략적 | 45 |
# | 청년 | 43 |
# | 중장년 | 43 |
# | 군인 | 42 |
# | 너드 | 40 |
# | 바람둥이 | 39 |
# | 능글맞음 | 39 |
# | 성실함 | 38 |
# | 형사(수사관) | 38 |
# | 검객/무사/검사 | 35 |
# | 배우 | 35 |
# | 평범 | 35 |
# | 기회주의자 | 34 |
# | 귀족 | 33 |
# | 사이코패스 | 32 |
# | 소년 영웅 | 32 |
# | 동성애자 | 31 |
# | 사기꾼 | 29 |
# | 깡패(조폭) | 28 |
# | 의적 | 26 |
# | 방어적임 | 24 |
# | 히어로 | 24 |
# | 츤데레 | 24 |
# | 프로듀서 | 23 |
# | 시한부 | 21 |
# | 까칠함 | 21 |
# | 냉정함 | 21 |
# | 남장/여장 | 19 |
# | 집착이 강함 | 19 |
# | 도둑(괴도) | 18 |
# | 금발 | 18 |
# | 과학자 | 17 |
# | 장애인 | 17 |
# | 몰락한 귀족 | 17 |
# | 아이돌 | 16 |
# | 귀신 | 16 |
# | 먼치킨/천재 | 16 |
# | 무능함 | 15 |
# | 악동 | 14 |
# | 애교있음 | 14 |
# | 노년 | 13 |
# | 운전수 | 13 |
# | 힘숨찐 | 13 |
#
# **빈도 9 이하 (40종)**
#
# 반인반수(수인)(11), 안티히어로(10), 호기심이 많음(9), 팜므파탈(9), 영유아(9), 호리호리함(9), 성경험이 없음(8), 살인청부업자(8), 예민함(7), 숨겨진 연인(7), 강도(7), 성직자(7), 돌연변이(7), 헌터(7), 마법사(마녀)(7), 조신함(6), 빌런(6), 하녀(시녀)(6), 유랑자(집시)(6), 간호사(5), 기사(5), 근육질(5), 황태자(5), 인질(4), 사채업자(4), 퇴마사(4), 사이보그(4), 복제인간(4), 자폐증(4), 뱀파이어(4), 다중인격(4), 골드디거(4), 밀매업자(3), 오만함(3), 열성(3), 음흉함(3), 트랜스젠더(3), 치매(3), 도사(3), 천사(3), 원작 속 악역(흑막)(3), 순수악(2), 창녀(2), 해적(2), 집착광공(2), 독재자(2), 전쟁포로(2), 초능력자(가이드)(2), 갈발(2), 섹스파트너(1), 간신배(1), 파산한 자본가(1), 혐관(1), 마법소녀(1), 절륜함(1), 차별주의자(1), 키다리 아저씨(1), 야만인(1), 초능력자(에스퍼)(1), 책사(1), 좀비(1), 첫사랑(1)
#
# ---
#
# ### 7-5. `stage` — 서사 단계 (씬 레벨)
#
# #### 스토리헬퍼 (storyhelper) — 총 16종
#
# > 5.2절 원본 문서의 15단계 목록과 실제 데이터에 사용된 레이블이 일부 다릅니다.
# > 실제 데이터에는 `Ups & Downs`, `Resurrection`, `Another Story`, `Final Salvo` 4종이 추가로 존재하며,
# > `Dark Night of Soul`, `Climax`, `Denouement` 3종은 데이터에서 확인되지 않습니다.
#
# | stage | 씬 수 |
# |-------|------:|
# | Setting-up | 8,380 |
# | 2nd Accident | 7,658 |
# | 1st Accident | 7,471 |
# | Making a Choice | 7,394 |
# | Doubts & Debate | 7,139 |
# | Villains Move | 6,516 |
# | Choice to Fight | 6,292 |
# | Defeat | 5,446 |
# | Main Character | 4,865 |
# | Innermost Cave | 4,546 |
# | Ups & Downs | 4,105 |
# | Resurrection | 3,963 |
# | Another Story | 3,836 |
# | Opening Salvo | 3,745 |
# | Final Salvo | 3,576 |
# | Trailer Moments | 3,492 |
#
# #### 영웅의 여정 (hero_journey) — 총 12종
#
# | stage | 씬 수 |
# |-------|------:|
# | 시험, 협력자, 적대자 | 299 |
# | 모험에의 소명 | 207 |
# | 시련 | 182 |
# | 일상세계 | 144 |
# | 동굴 가장 깊은 곳으로의 진입 | 116 |
# | 영약을 가지고 귀환 | 95 |
# | 부활 | 89 |
# | 정신적 스승과의 만남 | 82 |
# | 첫 관문의 통과 | 72 |
# | 귀환의 길 | 61 |
# | 소명부활의 거부 | 44 |
# | 보상 | 36 |
#
# ---
#
# ### 7-6. `unit_motif` — 씬 모티프 (씬 레벨)
#
# 총 **403종** / 83,206개 씬에 값 있음(92.6%) / 6,645개 씬은 null → `stage`로 fallback
#
# **빈도 200 이상 (100종)**
#
# | unit_motif | 씬 수 | | unit_motif | 씬 수 |
# |-----------|------:|-|-----------|------:|
# | 부탁/제안 | 3,227 | | 사랑 고백 | 441 |
# | 걱정 | 2,247 | | 적의 등장 | 427 |
# | 도움을 줌/받음 | 1,898 | | 성공 | 423 |
# | 계략을 꾸밈 | 1,844 | | 선물 줌/선물 받음 | 419 |
# | 결심 | 1,823 | | 여정의 시작 | 407 |
# | 상황 파악 | 1,618 | | 회의/논의 | 379 |
# | 감정의 표현 | 1,560 | | 첫눈에 반한 사랑 | 379 |
# | 말싸움/의견충돌 | 1,469 | | 해피엔딩 | 373 |
# | 추적/수색 | 1,346 | | 고민 해결 | 368 |
# | 비밀의 발견/발각 | 1,298 | | 간호/치료 | 365 |
# | 진솔한 대화 | 1,280 | | 시기/질투 | 348 |
# | 만남 | 1,211 | | 강제된 과업 | 341 |
# | 상황 설명 | 1,163 | | 아픔 | 340 |
# | 정보 획득 | 1,131 | | **복수** | **329** |
# | 불편한 만남 | 1,039 | | 사과함 | 321 |
# | 상황의 전말을 알게 됨 | 999 | | 동맹 | 315 |
# | 적과의 대치 | 968 | | 납치/감금 | 304 |
# | 회상 | 946 | | 매력을 느낌 | 303 |
# | 거짓말 | 914 | | **배신** | **302** |
# | 안좋은 예감 | 853 | | 전쟁/전투/토벌 | 301 |
# | 시련 | 823 | | 짝사랑 | 298 |
# | 죽음 | 810 | | 의외의 모습 | 297 |
# | 고뇌 | 796 | | 극복 | 291 |
# | 신경쓰임 | 794 | | 적대자들의 속내 | 289 |
# | 가족 불화 | 789 | | 귀환 | 287 |
# | 견제/정쟁/정치 | 788 | | 흔들리는 마음 | 285 |
# | 거절 | 740 | | 서러움 | 277 |
# | 긴장감 | 737 | | 가족 분열 | 268 |
# | 새로운 만남 | 725 | | 제보/신고/고발 | 265 |
# | 임무 수행 | 700 | | 덕담/응원 | 265 |
# | 도망/도피/잠적 | 699 | | 감정을 부정 | 262 |
# | 비밀의 공유 | 674 | | 공적인 입장표명 | 259 |
# | 의심 | 644 | | 뜻밖의 편지 | 259 |
# | 진실 고백 | 631 | | 친구가 됨 | 256 |
# | 현실(상황) 직면 | 609 | | 사랑하는 사람의 죽음 | 249 |
# | 조사/정찰 | 606 | | 설렘(일방) | 245 |
# | 상대를 의심 | 595 | | 갑작스런 사고 | 235 |
# | 기싸움 | 588 | | 취향의 재발견 | 235 |
# | 재회 | 582 | | 몰락/추락 | 232 |
# | 이별 | 579 | | 수련/훈련 | 226 |
# | 깨달음 | 575 | | 후회 | 225 |
# | 데이트 | 565 | | 폭행 | 219 |
# | 오해/착각 | 539 | | 보상 획득 | 218 |
# | 계략을 파악 | 534 | | 전투 준비 | 216 |
# | 냉정한 응대 | 514 | | 낯선 곳으로의 이주 | 215 |
# | 추궁 | 514 | | 바람/불륜 | 211 |
# | 조직(소속) 내 갈등 | 508 | | 현실 도피/회피성 도망 | 209 |
# | 협박 | 501 | | 선전포고 | 206 |
# | 우연한 만남 | 499 | | 약속 | 204 |
# | 실패 | 471 | | 조력자(후원자)를 만남 | 201 |
# | 적 제압/퇴치 | 470 | | 운명에 대한 반역 | 201 |
#
# **빈도 200 미만 전체 (303종)**
#
# 애정행각(196), 미행(194), 죄책감(189), 응징(184), 스킨십(184), 오해(착각)(183), 과거의 첫만남(181), 질투(180), 연인 상실(178), 탈출(175), 구세주 출현(174), 이지메(170), 세대를 초월한 우정(170), 데이트 준비(163), 동병상련(162), 능력 각성(156), 청소년기 일탈(155), 결혼(151), 거래(146), 도망자(145), 동료가 됨(전투/모험의 경우)(144), 술주정(139), 추격자(138), 가족(연인/친구)에 대한 협박(136), 적을 유인함(135), 부모/조부모의 죽음(135), 회의감(134), 잘못된 선택(132), 체념(131), 사기를 침/당함(131), 짝사랑의 비애(130), 거짓된 진술(129), 썸(쌍방)(128), 세간의 주목(128), 강박증(128), 모순 지적(126), 삼각관계(124), 수락(123), 신분위장(122), 가족분열(이산가족)(121), 출세주의자(119), 포기(118), 기억 회복(117), 대련/비무(116), 복수혈전(116), 희생하는 부모(116), 침입/잠입(115), 첫관계(115), 대전격투(113), 불청객(112), 바쁨(111), 전우 구출(111), 정당한 요구(109), 우월한 하급자(108), 죄의 고백(107), 예의 없는 행동(106), 선물 준비(106), 옛 연인의 출현(100), 범죄(99), 처벌(97), 프러포즈(96), 테러(95), 이혼(93), 조직(소속) 내 따돌림/폭력(93), 사랑의 연기(93), 첫눈에 반함(92), 불우한 천재(92), 입학/입사/입단/입문(91), 부당한 차별(91), 고발(91), 자퇴/퇴사/탈퇴/파문(90), 외상 후 스트레스성 장애(PTSD)(90), 재결합(88), 덜떨어진 영웅(88), 희생(87), 팜므파탈(요부)(87), 가스라이팅(86), 결혼 재촉(85), 지리적 고립(85), 중년의 위기(85), 도제수련(84), 돈을 노리는 유혹자(Gold Digger)(84), 용서(83), 삼자대면(83), 세력다툼(81), 여정(81), 연쇄 살인(80), 고뇌하는 깡패(78), 계급을 초월한 사랑(78), 현실 도피 욕구(77), 해명(76), 옛 연인 회상(75), 충동적 스킨십(75), 연인의 죽음(74), 기억 상실(74), 오늘부터 1일(연애 시작)(74), 버려진 아이(73), 지배자 희롱(72), 제자에 대한 걱정(71), 우울증(70), 개과천선(69), 고등사기꾼(69), 광기어린 사랑(67), 밀당(66), 명예손상(65), 도둑(65), 살인청부업자(64), 동거(63), 탈옥(63), 사고사(62), 아웃사이더(62), 기억 왜곡/세뇌/착란(61), 육아(61), 납치(61), 고립된 남녀(61), 대항해와 원정(59), 비대칭전투(57), 배반자(57), 누명(57), 우발적 살인(57), 임신을 알게됨(56), 과잉보호(56), 기이한 선생(56), 상상(55), 부부싸움(54), 취중진담(53), 시한부 선고(52), 미결의 살인사건(52), 갑작스런 병(52), 존경/동경(50), 악동(50), 망한 키스(49), 나쁜남자에게 반하기(49), 소년 영웅(49), 회귀(48), 희생하는 자식(48), 강도(48), 수줍음/용기없음(47), 관계(스킨십) 후 후회(47), 도시 재난(46), 노년기 과제(46), 수사의뢰(45), 동물과의 우정(45), 동거 제안(44), 수장끼리의 싸움(일기토)(44), 부모 찾기(44), 숨겨진 연인(44), 바람둥이(44), 빙의(43), 첫인상이 별로임(43), 부패경찰(43), 수수께끼(43), 보물찾기(43), 신고식(42), 아름다운 불륜(42), 몰락한 귀족(41), 징계위원회(41), 악마와의 계약(41), 똑똑한 바보(40), 감금(40), 야망(39), 능력의 대가(패널티/핸디캡)(39), 전쟁 발발(39), 구혼시험(39), 자각 없는 짝사랑(38), 미지의 후견인(38), 귀향(38), 정의 따윈 없어(37), 특수한 능력 획득(36), 유령(36), 알코올 중독(36), 횡재(35), 돌연변이(뮤턴트)(35), 성정체성 혼란(34), 저주받은 장소(34), 집단광기(33), 대학살(33), 이계방문(33), 사이코패스(33), 형제 간의 경쟁(32), 사이다(31), 자살(30), 뇌물을 줌/받음(29), 스토킹(29), 뱀파이어(29), 적군과의 우정(29), 환생(28), 가문의 여주인(28), 독재정치(28), 외계인 침입(28), 졸업/은퇴(27), 시집살이/고부갈등(27), 스킬 획득(26), 이간질(26), 원나잇스탠드(26), 예언(25), 귀신소환(25), 사랑의 도피(24), 사랑 따윈 없어(24), 나이 차를 극복한 사랑(24), 모반(24), 마약거래자(24), 아동학대(24), 출산(23), PTSD 발작(23), 강간(23), 악마적인 예술가(23), 인질(23), 학대하는 계부(계모)(23), 유랑자(집시)(23), 용서할 준비(22), 반인반수(22), 거대괴수(21), 감춰진 혈통찾기(21), 상위 계급과 친구가 됨(20), 고귀한 창녀(20), 뜻밖의 초능력(20), 간통(20), 지인의 실종(20), 창녀(20), 무장봉기(20), 날 무시한(때린) 사람은 네가 처음이야(19), 기억상실증(19), 저주(19), 천사(19), 프러포즈 준비(18), 입양(18), 순교자(18), 식민지화(18), 던전 토벌(18), 필름끊김(17), 처녀영웅(17), 마조히즘(17), 마법사(마녀)(17), 악마의 아이(16), 경계성 인격장애(16), 아동 유괴(16), 적과의 사랑(16), 고귀한 하녀(16), 상견례(15), 고리대금업자(15), 사랑에 빠진 노인(15), 동성애자(15), 장애인(15), 생물학 재앙(14), 고상한 야만인(14), 파산(14), 용호상박(14), 무인도 조난(13), 파업(13), 첫사랑의 끝(12), 퇴마사(12), 동반자살(12), 도박(12), 전쟁포로(12), 하위 계급과 친구가 됨(11), 신분상승결혼(신데렐라)(11), 천재지변(11), 미래/원작 지식 활용(10), 다중인격(10), 백치미인(10), 아내강탈(10), 시간여행(10), 약혼(9), 사디즘(9), 변장(9), 자폐증(9), 파혼(8), 의처증(의부증)(8), 위험한 비밀결혼(8), 사이보그(8), 지구종말(8), 관음증(8), 성생활 장애(8), 근친상간(8), 복제인간(7), 피그말리온(7), 의적(7), 치매(6), 미친 전도사(6), 도플갱어(6), 공황장애(6), 대체역사(5), 사람이 된 인형(5), 파계(5), 불면증(5), 호모 슈페리얼(4), 저승방문자(4), 뱀파이어 헌터(4), 롤리타(3), 입덧(2), 좀비(2), 고부갈등(2), 시라노 콤플렉스(2), 인공동면(1)
#
# ---
#
# ### 7-7. `emotion` — 감정 레이블 (story_scripts 레벨)
#
# 총 **89종** / 씬별 Top2를 `dominant_emotions`로 집계 → scene_index에 저장
# 구조 설계에서는 stage별 지배 감정 Top3를 `top_emotions_by_stage`로 집계
#
# > `emotion`은 story_scripts(문장 레벨) 필드이므로 씬 단위로 집계 후 사용합니다.
# > 씬 내 가장 자주 나온 감정 2개를 `dominant_emotions` 리스트로 저장합니다.
#
# **빈도 높은 순 (샘플 기준)**
#
# | 감정 | | 감정 | | 감정 |
# |------|--|------|--|------|
# | 담담하다 | | 기대되다 | | 자신감 있다 |
# | 궁금하다 | | 즐겁다 | | 반갑다 |
# | 단호하다 | | 짜증나다 | | 미안하다 |
# | 놀라다 | | 비장하다 | | 괴롭다 |
# | 긴장되다 | | 난감하다 | | 무섭다 |
# | 걱정 | | 의심스럽다 | | 뻔뻔하다 |
# | 화나다 | | 기쁘다 | | 초조하다 |
# | 당황하다 | | 불안하다 | | 만족하다 |
# | — | | 안타깝다 | | 괘씸하다 |
#
# **전체 89종 (빈도 낮은 순)**
#
# 답답하다, 심란하다, 슬프다, 씁쓸하다, 후련하다, 설레다, 외롭다, 그립다, 허탈하다, 두렵다, 억울하다, 창피하다, 부럽다, 아프다, 행복하다, 쑥스럽다, 피곤하다, 무기력하다, 절망스럽다, 분하다, 혼란스럽다, 원망스럽다, 의기양양하다, 감동하다, 안도하다, 떨리다, 지루하다, 창피스럽다, 착잡하다, 미칠것같다, 당혹스럽다, 수치스럽다, 자괴감이 들다, 실망하다, 조급하다, 오싹하다, 열등하다, 흥분하다, 설득력있다, 맹렬하다, 야망있다, 잔인하다, 냉혹하다, 집착하다, 속상하다, 무관심하다, 거만하다, 공허하다, 연민, 갈망하다, 포기하다, 유혹하다, 오해하다, 자책하다, 흐뭇하다, 경계하다, 간절하다, 비참하다, 웅장하다, 뿌듯하다
